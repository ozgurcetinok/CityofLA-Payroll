# %%
import pandas as pd
data = pd.read_csv("City_Employee_Payroll.csv")
# Out:
# /Users/ozgurcetinok/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (4,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head(10)
#pd.read_csv(sio, dtype={"user_id": int, "username": object})
# Out:
#                   Row ID  Year           Department Title  Payroll Department  \
# 0       3-1000027830ctFu  2013              Police (LAPD)              4301.0
# 1       3-1000155488ctFu  2013              Police (LAPD)              4302.0
# 2       3-1000194958ctFu  2013              Police (LAPD)              4301.0
# 3       3-1000198958ctFu  2013                        Zoo              8701.0
# 4       3-1000232317ctFu  2013              Police (LAPD)              4301.0
# 5       3-1000329284ctFu  2013              Police (LAPD)              4302.0
# 6       3-1000364472ctFu  2013  Public Works - Sanitation              7026.0
# 7   3-1000560683dwp941Fu  2013      Water And Power (DWP)                 NaN
# 8  3-1000674587dwp1835Fu  2013      Water And Power (DWP)                 NaN
# 9         3-10007663ctFu  2013                  Personnel              2001.0
#
#   Record Number                 Job Class Title Employment Type  \
# ...

# %%
len(list(data))
# Out:
# 35

# %%
df = data[data.duplicated(subset=['Year','Record Number'], keep=False)]

# %%
df
# Out:
#                        Row ID  Year                Department Title  \
# 36           3-1002241970ctFu  2013      Public Works - Engineering
# 37           3-1002241970ctPa  2013      Public Works - Engineering
# 95           3-1008293054ctPe  2013            Recreation And Parks
# 117          3-1007452076ctFu  2013                General Services
# 118          3-1007452076ctPa  2013                      City Clerk
# 125           3-100802199ctFu  2013  Public Works - Street Services
# 126      3-100802199dwp1611Fu  2013           Water And Power (DWP)
# 132          3-1008225206ctFu  2013  Public Works - Street Services
# 133          3-1008225206ctPa  2013                      City Clerk
# 135          3-1008293054ctPa  2013            Recreation And Parks
# 148          3-1009299705ctFu  2013                   Police (LAPD)
# 149          3-1009299705ctPa  2013                      City Clerk
# 198          3-1012402810ctFu  2013  Public Works - Street Services
# ...

# %%
len(data["Record Number"])
# Out:
# 358009

# %%
data["Year"].unique()
# Out:
# array([2013, 2014, 2015, 2018, 2016, 2017])

# %%
len(data["MOU Title"].unique())
# Out:
# 187

# %%
len(data["Payroll Department"].unique())
# Out:
# 195

# %%
len(data["Department Title"].unique())
# Out:
# 88

# %%
len(data["Job Class Title"].unique())
# Out:
# 1696

# %%
data["Employment Type"].unique()
# Out:
# array(['Full Time', 'Part Time', 'Per Event'], dtype=object)

# %%
import numpy as np
np.dtype(data["Employment Type"])
# Out:
# dtype('O')

# %%
data=data.drop(["Row ID", "Job Class Link","MOU","Job Class","FMS Department","Total Payments","% Over Base Pay","Other Pay (Payroll Explorer)","Payments Over Base Pay","Average Health Cost","Average Dental Cost","Average Basic Life"],axis = 1)

# %%
data.head(10)
# Out:
#    Year           Department Title  Payroll Department Record Number  \
# 0  2013              Police (LAPD)              4301.0    1000027830
# 1  2013              Police (LAPD)              4302.0    1000155488
# 2  2013              Police (LAPD)              4301.0    1000194958
# 3  2013                        Zoo              8701.0    1000198958
# 4  2013              Police (LAPD)              4301.0    1000232317
# 5  2013              Police (LAPD)              4302.0    1000329284
# 6  2013  Public Works - Sanitation              7026.0    1000364472
# 7  2013      Water And Power (DWP)                 NaN    1000560683
# 8  2013      Water And Power (DWP)                 NaN    1000674587
# 9  2013                  Personnel              2001.0      10007663
#
#                   Job Class Title Employment Type  Hourly or Event Rate  \
# 0             Police Detective II       Full Time                 53.16
# ...

# %%
df = data.head(10)

# %%
print(pd.get_dummies(df))
# Out:
#    Year  Payroll Department  Hourly or Event Rate  Projected Annual Salary  \
# 0  2013              4301.0                 53.16                110998.08
# 1  2013              4302.0                 23.77                 49623.67
# 2  2013              4301.0                 60.80                126950.40
# 3  2013              8701.0                 30.23                 63126.77
# 4  2013              4301.0                 60.98                127326.24
# 5  2013              4302.0                 45.06                 94076.67
# 6  2013              7026.0                 45.60                 95212.80
# 7  2013                 NaN                   NaN                 59278.32
# 8  2013                 NaN                   NaN                 78613.20
# 9  2013              2001.0                 35.07                 73226.16
#
#    Q1 Payments  Q2 Payments  Q3 Payments  Q4 Payments   Base Pay  \
# 0     24931.20     29181.61     26545.80     29605.30  105764.79
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358009 entries, 0 to 358008
# Data columns (total 23 columns):
# Year                       358009 non-null int64
# Department Title           358009 non-null object
# Payroll Department         289906 non-null float64
# Record Number              358009 non-null object
# Job Class Title            358009 non-null object
# Employment Type            358009 non-null object
# Hourly or Event Rate       278001 non-null float64
# Projected Annual Salary    299022 non-null float64
# Q1 Payments                299022 non-null float64
# Q2 Payments                299022 non-null float64
# Q3 Payments                299022 non-null float64
# Q4 Payments                299022 non-null float64
# Base Pay                   299022 non-null float64
# Permanent Bonus Pay        299022 non-null float64
# Longevity Bonus Pay        299022 non-null float64
# Temporary Bonus Pay        299022 non-null float64
# ...

# %%
data[data['Record Number'] == 1000027830]
# Out:
#                   Row ID  Year Department Title  Payroll Department  \
# 0       3-1000027830ctFu  2013    Police (LAPD)              4301.0
# 57396   4-1000027830ctFu  2014    Police (LAPD)              4301.0
# 114355  5-1000027830ctFu  2015    Police (LAPD)              4301.0
# 175639  7-1000027830ctFu  2017           Police              4301.0
# 239011  6-1000027830ctFu  2016    Police (LAPD)              4301.0
# 299812  8-1000027830ctFu  2018    Police (LAPD)              4301.0
#
#        Record Number      Job Class Title Employment Type  \
# 0         1000027830  Police Detective II       Full Time
# 57396     1000027830  Police Detective II       Full Time
# 114355    1000027830  Police Detective II       Full Time
# 175639    1000027830  Police Detective II       Full Time
# 239011    1000027830  Police Detective II       Full Time
# 299812    1000027830  Police Detective II       Full Time
#
#         Hourly or Event Rate  Projected Annual Salary  Q1 Payments  \
# ...

# %%
new = data[data['Year'] == 2018]

# %%
len(new["Record Number"])
# Out:
# 58987

# %%
nnew = new.dropna(axis='columns')

# %%
list(nnew)
# Out:
# ['Row ID',
#  'Year',
#  'Department Title',
#  'Record Number',
#  'Job Class Title',
#  'Employment Type',
#  'MOU',
#  'MOU Title',
#  'FMS Department',
#  'Job Class',
#  'Job Class Link']

# %%
data[(data['Year'] == 2018) & (data['FMS Department'] == 86)]
# Out:
#                   Row ID  Year                Department Title  \
# 299477  8-1468906072ctFu  2018  Public Works - Street Services
# 299603  8-2523046798ctFu  2018  Public Works - Street Services
# 299646  8-2875477885ctFu  2018  Public Works - Street Services
# 299671  8-3187367514ctFu  2018  Public Works - Street Services
# 299679  8-3255911619ctFu  2018  Public Works - Street Services
# 299770    8-56826368ctFu  2018  Public Works - Street Services
# 299830  8-1004847165ctFu  2018  Public Works - Street Services
# 299842  8-1005624475ctFu  2018  Public Works - Street Services
# 299862  8-1006664476ctFu  2018  Public Works - Street Services
# 299879   8-100802199ctFu  2018  Public Works - Street Services
# 299960  8-1013020041ctFu  2018  Public Works - Street Services
# 299964  8-1013212291ctFu  2018  Public Works - Street Services
# 299996  8-1015897747ctFu  2018  Public Works - Street Services
# 300026   8-101783908ctFu  2018  Public Works - Street Services
# ...

# %%
data18 = pd.read_csv("payroll_2018.csv")

# %%
len(data18["Record.Number"])
# Out:
# 53674

# %%
data18.head(10)
# Out:
#    Record.Number  Q1.Q2Payments.2018  Unnamed: 2
# 0   1.052058e+09                 NaN         NaN
# 1   1.307828e+09                 NaN         NaN
# 2   1.527199e+09                 NaN         NaN
# 3   1.576461e+09                 NaN         NaN
# 4   1.582203e+09                 NaN         NaN
# 5   1.933839e+09                 NaN         NaN
# 6   2.035637e+09                 NaN         NaN
# 7   2.111665e+09                 NaN         NaN
# 8   2.159092e+09                 NaN         NaN
# 9   2.220198e+09                 NaN         NaN

# %%
data[data['Record Number'] == 1002241970]
# Out:
#                   Row ID  Year            Department Title  \
# 36      3-1002241970ctFu  2013  Public Works - Engineering
# 37      3-1002241970ctPa  2013  Public Works - Engineering
# 57434   4-1002241970ctFu  2014  Public Works - Engineering
# 114395  5-1002241970ctFu  2015  Public Works - Engineering
# 177198  7-1002241970ctFu  2017  Public Works - Engineering
# 239050  6-1002241970ctFu  2016  Public Works - Engineering
# 299744  8-1002241970ctFu  2018  Public Works - Engineering
#
#         Payroll Department Record Number           Job Class Title  \
# 36                  6201.0    1002241970              Systems Aide
# 37                  6201.0    1002241970              Systems Aide
# 57434               6201.0    1002241970        Systems Analyst II
# 114395              6201.0    1002241970       Senior Clerk Typist
# 177198              6201.0    1002241970           Systems Analyst
# 239050              6201.0    1002241970        Systems Analyst II
# ...

# %%
data[data['Record Number'] == 1000198958]
# Out:
#                   Row ID  Year Department Title  Payroll Department  \
# 3       3-1000198958ctFu  2013              Zoo              8701.0
# 57399   4-1000198958ctFu  2014              Zoo              8701.0
# 114358  5-1000198958ctFu  2015              Zoo              8701.0
# 239013  6-1000198958ctFu  2016              Zoo              8701.0
#
#        Record Number           Job Class Title Employment Type  \
# 3         1000198958  Light Equipment Operator       Full Time
# 57399     1000198958  Light Equipment Operator       Full Time
# 114358    1000198958  Light Equipment Operator       Full Time
# 239013    1000198958  Light Equipment Operator       Full Time
#
#         Hourly or Event Rate  Projected Annual Salary  Q1 Payments  \
# 3                      30.23                 63126.77     15319.59
# 57399                  31.85                 66505.67     16503.14
# 114358                 31.92                 66657.83     16517.69
# ...

# %%
data["Department Title"] = pd.to_numeric(data["Department Title"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Police (LAPD)"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-b1e0f2d5d13b> in <module>()
# ----> 1 data["Department Title"] = pd.to_numeric(data["Department Title"])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     131             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     132             values = lib.maybe_convert_numeric(values, set(),
# --> 133                                                coerce_numeric=coerce_numeric)
#     134
#     135     except Exception:
#
# ...

# %%
import statsmodels.api as sm
import numpy as np
X = data.drop(["Q1 Payments"],axis=1)
y = data["Q1 Payments"]
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-06232f3f35ee> in <module>()
#       3 X = data.drop(["Q1 Payments"],axis=1)
#       4 y = data["Q1 Payments"]
# ----> 5 model = sm.OLS(y, X).fit()
#       6 predictions = model.predict(X)
#       7 model.summary()
#
# ~/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     629                  **kwargs):
#     630         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 631                                   hasconst=hasconst, **kwargs)
#     632         if "weights" in self._init_keys:
#     633             self._init_keys.remove("weights")
#
# ~/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
# ...

# %%
X=data[["Q1 Payments","Q2 Payments","Q3 Payments","Q4 Payments","Total Payments"]].head(10)

# %%
X['sum'] = X.sum(axis=1)

# %%
X
# Out:
#    Q1 Payments  Q2 Payments  Q3 Payments  Q4 Payments  Total Payments  \
# 0     24931.20     29181.61     26545.80     29605.30       110263.91
# 1     11343.96     13212.37     11508.36     13442.53        49507.22
# 2     24184.00     28327.20     28744.20     33224.88       114480.28
# 3     15319.59     17762.14     15601.85     18233.32        66916.90
# 4     29391.20     36591.20     32904.81     37234.03       136121.24
# 5     20813.00     24136.00     21517.76     25231.29        91698.05
# 6     20937.60     24427.20     21729.60     25536.00        92630.40
# 7     19260.07     15752.00         0.00         0.00        35012.07
# 8     25113.36     25864.16     19020.84     24131.71        94130.07
# 9     16307.60     19348.00     16792.00     19639.20        72086.80
#
#          sum
# 0  220527.82
# 1   99014.44
# 2  228960.56
# 3  133833.80
# 4  272242.48
# 5  183396.10
# 6  185260.80
# 7   70024.14
# 8  188260.14
# 9  144173.60

# %%
Y=data[["Permanent Bonus Pay","Longevity Bonus Pay","Temporary Bonus Pay","Lump Sum Pay","Other Pay & Adjustments","Other Pay (Payroll Explorer)"]].head(10)
Y['sum'] = Y.sum(axis=1)
Y
# Out:
#    Permanent Bonus Pay  Longevity Bonus Pay  Temporary Bonus Pay  \
# 0              3174.12                 0.00               1325.0
# 1                 0.00              1310.82                  0.0
# 2              7363.95                 0.00               1205.0
# 3              3446.79              1677.29                800.0
# 4              7086.67                 0.00               1325.0
# 5                 0.00              1251.19                125.0
# 6                 0.00                 0.00                  0.0
# 7                 0.00                 0.00                  0.0
# 8                 0.00                 0.00                  0.0
# 9                 0.00                 0.00                  0.0
#
#    Lump Sum Pay  Other Pay & Adjustments  Other Pay (Payroll Explorer)  \
# 0          0.00                     0.00                       4499.12
# 1          0.00                   534.00                       1844.82
# ...

# %%
data["Pay Grade"].unique()
# Out:
# array(['2', '0', '1', nan, '3', 'B', '5', 'G', 'D', '6', 'C', 'A', '4',
#        '9', 'F', 'E', 'H', '7', '8', 'M', 'O', 'J', 'Y', 'N', 'V', 'U',
#        'S', 'L', 'P', 'K', 'Z', 'W', 'T', 'X'], dtype=object)

# %%
import numpy as np
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

XX = data.dropna()
XX = XX._get_numeric_data() #drop non-numeric cols

XX.head(10)
# Out:
# /Users/ozgurcetinok/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
#     Year  Payroll Department  Hourly or Event Rate  Projected Annual Salary  \
# 0   2013              4301.0                 53.16                110998.08
# 1   2013              4302.0                 23.77                 49623.67
# 2   2013              4301.0                 60.80                126950.40
# 3   2013              8701.0                 30.23                 63126.77
# 4   2013              4301.0                 60.98                127326.24
# 5   2013              4302.0                 45.06                 94076.67
# 6   2013              7026.0                 45.60                 95212.80
# 9   2013              2001.0                 35.07                 73226.16
# ...

# %%
# %%capture
#gather features
features = "+".join(XX.columns.drop("Projected Annual Salary"))
y, X = dmatrices('Projected Annual Salary ~' + features, XX, return_type='dataframe')
# Out:
# Traceback (most recent call last):
#
#   File "/Users/ozgurcetinok/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-89-bb5295765396>", line 3, in <module>
#     y, X = dmatrices('Projected Annual Salary ~' + features, XX, return_type='dataframe')
#
#   File "/Users/ozgurcetinok/anaconda3/lib/python3.6/site-packages/patsy/highlevel.py", line 310, in dmatrices
#     NA_action, return_type)
#
#   File "/Users/ozgurcetinok/anaconda3/lib/python3.6/site-packages/patsy/highlevel.py", line 165, in _do_highlevel_design
#     NA_action)
#
#   File "/Users/ozgurcetinok/anaconda3/lib/python3.6/site-packages/patsy/highlevel.py", line 70, in _try_incr_builders
#     NA_action)
#
#   File "/Users/ozgurcetinok/anaconda3/lib/python3.6/site-packages/patsy/build.py", line 689, in design_matrix_builders
# ...

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
# Out:
# /Users/ozgurcetinok/anaconda3/lib/python3.6/site-packages/statsmodels/stats/outliers_influence.py:167: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
features
# Out:
# 'Year+Payroll Department+Hourly or Event Rate+Q1 Payments+Q2 Payments+Q3 Payments+Q4 Payments+Base Pay+Permanent Bonus Pay+Longevity Bonus Pay+Temporary Bonus Pay+Lump Sum Pay+Overtime Pay+Other Pay & Adjustments+Average Benefit Cost'
